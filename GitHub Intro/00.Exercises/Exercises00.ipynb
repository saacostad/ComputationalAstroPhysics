# %% [markdown]
# ![Astrofisica Computacional](../../../new_logo.png)

# %% [markdown]
# # Computational Astrophysics 2026-I
# ## 00. Exercises

# %% [markdown]
# ##  Git and GitHub
#
# 1. Open a free account at www.github.com
#
# 2. Install Git on your personal computer.
#
# 3. Clone the repository of the Computational Astrophysics course,
# https://github.com/Hypnus1803/ComputationalAstrophysics_2026-I
#
# 4. Create a repository in GitHub to store and share the answers to the exercises in this course.
#
# 5. Create a folder with the name "00.Exercises" in your repository and put this file in it.
#
# 6. Complete the information in the next cell and commit the changes to your repository.
#
# 7. Share your repository in the Google Classroom assignment

# %% [markdown]
# ### Complete the Following Information
#
# **Name:** Santiago Andrés Acosta Díaz
#
# **Code:** 1025140089
#
# **Career and level:** Physics, undergraduate
#
# **e-mail:** saacostad@unal.edu.co
